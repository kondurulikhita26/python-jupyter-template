# %% [markdown]
# ### Exercise 3: Scatter Plot with Annotations

# %%
# TASK: Create a scatter plot with x = [1, 2, 3, 4, 5] and y = [2, 4, 6, 8, 10].
# Annotate each point with its (x, y) value, and set the title as 'Scatter Plot with Annotations'.
import matplotlib.pyplot as plt
# Define x and y values
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create the scatter plot
plt.scatter(x, y, color='blue', marker='o')

# Annotate each point with its (x, y) value
for i in range(len(x)):
    plt.text(x[i], y[i], f'({x[i]}, {y[i]})', fontsize=10, ha='right')

# Customizations
plt.title('Scatter Plot with Annotations')  # Adding a title
plt.xlabel('X Values')  # Label for X-axis
plt.ylabel('Y Values')  # Label for Y-axis

# Display the plot
plt.show()
